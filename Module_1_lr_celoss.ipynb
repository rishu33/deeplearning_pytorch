# %% [markdown]
# ### Module 1: Logistic Regressing Cross Entropy Loss

# %% [markdown]
# #### Outline
#
# * Problem with Mean Squared Error
# * Maximum Likelihood
# * Logistic Regression Cross Entropy

# %% [markdown]
# #### Loss/Cost function
#
# Here:
#
# *y<sub>n</sub>* = 0 (red) ; 1 (blue)
# THR (Threshold Function) = 1 (if correctly classified) ; 0 (if incorrectly classified)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# IF THR = 1 (if correctly classified) ; 0 (if incorrectly classified)
# ![image.png](attachment:image.png)
#
# IF THR = Sigmoid
# ![image-2.png](attachment:image-2.png)
#
# IF THR = Likelihood Function
# ![image-3.png](attachment:image-3.png)
#
# NOTE : We go further with this Likelihood Function

# %% [markdown]
# #### Logistic Regression
#
# Coming to NLL using Likelihood Function
# ![image.png](attachment:image.png)
#
# Final Expression of Cross Entropy Loss
# ![image-2.png](attachment:image-2.png)
#
# Now we create a basic Model in Pytorch.

# %%
import pytorch
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
