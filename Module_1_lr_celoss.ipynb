# %% [markdown]
# ### Module 1: Logistic Regressing Cross Entropy Loss (THEORY)

# %% [markdown]
# #### Outline
#
# * Problem with Mean Squared Error
# * Maximum Likelihood
# * Logistic Regression Cross Entropy

# %% [markdown]
# #### 1. Problem with Mean Squared Error
#
# ![image.png](attachment:image.png)
#
# here:
# *y<sub>n</sub>* = 0 (red) ; 1 (blue)
# THR (Threshold Function) = 1 (if correctly classified) ; 0 (if incorrectly classified)

# %% [markdown]
# IF THR = 1 (if correctly classified) ; 0 (if incorrectly classified)
# THEN the during gradient descent the gradient becomes 0, leading to model training getting stuck.
# ![image.png](attachment:image.png)
#
# IF THR = Sigmoid
# THEN there is some value of gradient (of loss function) present throughout the scope.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 2. Maximum Likelihood
#
# IF THR = Likelihood Function in computation for Loss
# THEN we still get some gradient values (since it has Sigmoid in it)
# ![image-3.png](attachment:image-3.png)
# NOTE : We go further with this Likelihood Function
#
# Modifying Likelihood function
# ![image.png](attachment:image.png)
#
# Final Expression (This is called Cross Entropy Loss)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 3. Logistic Regression in Pytorch
#
# ##### Building Model
# (one way)
# ![image.png](attachment:image.png)
#
# (Another Way)
# ![image-3.png](attachment:image-3.png)
#
# ##### Loss Functions
#
# 1. Mean Squared Error (MSE)
# ![image-2.png](attachment:image-2.png)
# or criterion = nn.MSELoss()
#
# 2. Cross Entropy Loss
# criterion = nn.BCELoss()
